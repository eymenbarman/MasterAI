# %%
#pip install cvlib

# %%
#pip install opencv-python

# %% [markdown]
# ### Auto ML gibi Auto Computer Vision Yapmak

# %%
import cv2
import matplotlib.pyplot as plt
import cvlib
from cvlib.object_detection import draw_bbox

# %%
img=cv2.imread('cars.jpg')

# %%
plt.imshow(img)

# %%
box,label,count= cvlib.detect_common_objects(img)
# Out:
# Downloading yolov4.cfg from https://raw.githubusercontent.com/AlexeyAB/darknet/master/cfg/yolov4.cfg
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-868e1a6c7c2f> in <cell line: 0>()
# ----> 1 box,label,count= cvlib.detect_common_objects(img)
#
# /usr/local/lib/python3.11/dist-packages/cvlib/object_detection.py in detect_common_objects(image, confidence, nms_thresh, model, enable_gpu)
#     113
#     114     if not os.path.exists(config_file_abs_path):
# --> 115         download_file(url=cfg_url, file_name=config_file_name, dest_dir=dest_dir)
#     116
#     117     if not os.path.exists(weights_file_abs_path):
#
# /usr/local/lib/python3.11/dist-packages/cvlib/utils.py in download_file(url, file_name, dest_dir)
#      40         for chunk in  r.iter_content(chunk_size=chunk_size):
#      41             file.write(chunk)
# ---> 42             bar.update(count)
#      43             count +=1
#      44
#
# /usr/local/lib/python3.11/dist-packages/progressbar/progressbar.py in update(self, value)
#     248                 and not 0 <= value <= self.maxval):
#     249
# --> 250                 raise ValueError('Value out of range')
#     251
#     252             self.currval = value
#
# ValueError: Value out of range

# %%
output=draw_bbox(img,box,label_count)

# %%
plt.figure(figsize=(10,10))
plt.imshow(output)

# %%
label.count('car)
# Out:
#   File "<ipython-input-9-5dfed70cc8d9>", line 1
#     label.count('car)
#                 ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
label.count('person')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-51a8611f7879> in <cell line: 0>()
# ----> 1 label.count('person')
#
# NameError: name 'label' is not defined
